# %% [markdown]
# # Control Structures

# %%
#underage
age=25
if age <18 :
    print("you are under age")
    print("you can't drink alochol")
    print("you can't enter into bar")
    print("you can't get an ID")
else:
    print("You can get all that")
# Out:
# You can get all that

# %%
from IPython.core.inputtransformer2 import ESC_HELP
#multiple conditions -elseif

monthly_income=500

if monthly_income<=5000:
   print ("low income")

elif monthly_income<=15000:
    print("middle income")
else:
     print("high income")
# Out:
# low income

# %%
# Assign A, B, C, D & E for over 80 , above 70 ,60, 50 and below 50 repective

marks= 70
if marks >=80:
  print("A")
elif marks>=70:
  print("B")
elif marks >=60:
  print("C")
elif marks>=50:
  print("D")
else :
  print("E")
# Out:
# B

# %%
temperture = 30

if temperture >25:
  print("its hot")


else:

 print("its cold")
# Out:
# its hot

# %%
#Classifying Household Size (NGO Work)
household_size = 7


if household_size >= 6:
    print("Large household - Priority assistance")

else:
      print("Standard household")
# Out:
# Large household - Priority assistance

# %%
#Age-Based Health Services
child_age = 4

if child_age < 5:
         print("Eligible for under-5 clinic")
else:

     print("Refer to general clinic")
# Out:
# Eligible for under-5 clinic

# %%
#Water Distribution Analysis
liters_collected = 18

if liters_collected < 15:
  print("Below minimum - needs attention")
else:
  print("Adequate water supply")
# Out:
# Adequate water supply

# %%
#Multiple Categories with elif
monthly_income = 8000

if monthly_income < 5000:
 print("Low income")
elif monthly_income < 15000:
 print("Middle income")
else:
  print("High income")
# Out:
# Middle income

# %%
#Education Level Classification

years_of_education = 10

if years_of_education >= 12:
    print("Secondary education completed")

elif years_of_education >= 8:
  print("Primary education completed")
elif years_of_education >= 1:
  print("Some education")

else:
  print("No formal education")
# Out:
# Primary education completed

# %%
#Nutrition Status Assessment
muac_cm = 11.8

if muac_cm < 11.5:
  print("Severe malnutrition - immediate referral")
elif muac_cm < 12.5:
 print("Moderate malnutrition - supplementary feeding")
else:
 print("Normal nutrition status")
# Out:
# Moderate malnutrition - supplementary feeding
